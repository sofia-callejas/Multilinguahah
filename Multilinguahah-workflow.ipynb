# %% [markdown]
# # Multilinguahah: Full Pipeline Testing"
#
# This notebook demonstrates the complete workflow: environment setup, preprocessing, feature extraction, model training/inference, formatting, and final evaluation.

# %%
import os
import os.path as osp
DATA_DIR = "/home/scallejas/data/train"
LABELS_DIR = "/home/scallejas/data/test"
MODELS_DIR = "/home/scallejas/data/text-model/laughter_detection/validaciones_nahuel"
RESULTS_DIR = "/home/scallejas/results_notebook"
METHOD = "isolation"
LANG = "fr"
EMBEDDING = "byola-f"
METHOD = "isolation"
os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(osp.join(RESULTS_DIR, "csv_preds"), exist_ok=True)
os.makedirs(osp.join(RESULTS_DIR, "metrics"), exist_ok=True)

# %% [markdown]
# ## 1. Environment Setup

# %%
# !pip install -r requirements.txt
# !bash setup.sh

# %% [markdown]
# ## 2. Preprocessing & Feature Extraction

# %%
# !python remove_voice.py {osp.join(DATA_DIR, LANG)}
# !python get_embeddings.py {osp.join(DATA_DIR, LANG)} --embedding-name {EMBEDDING}
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.

# %% [markdown]
# ## 3. Training & Inference

# %%
# !python main.py --root_dir {DATA_DIR} --labels_dir {LABELS_DIR} --embedding_name {EMBEDDING} --method {METHOD} --task train_isolation
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ^C

# %% [markdown]
# ## 4. Evaluation

# %%
PRED_LANG_DIR = osp.join(DATA_DIR,"laughter" ,LANG, EMBEDDING,METHOD)
LABEL_LANG_DIR = osp.join(LABELS_DIR, LANG,"audio","labels")

METRICS_OUT_DIR = osp.join(RESULTS_DIR,"metrics")
IOU_THRESHOLD = 0.7

# !python evaluation/evaluate_dataset.py {PRED_LANG_DIR} {LABEL_LANG_DIR} {METRICS_OUT_DIR} {IOU_THRESHOLD} --method multilinguahah
